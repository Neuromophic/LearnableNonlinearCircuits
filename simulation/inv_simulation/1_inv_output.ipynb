# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize as op
import math
import torch

# %%
data = pandas.read_csv('../result/invW_10000.csv')
data
# Out:
# /opt/bwhpc/common/jupyter/base/2022-03-30/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3106: DtypeWarning: Columns (3043,3044) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       dc (V)  \
# 0     -2.000
# 1     -1.999
# 2     -1.998
# 3     -1.997
# 4     -1.996
# ...      ...
# 3996   1.996
# 3997   1.997
# 3998   1.998
# 3999   1.999
# 4000   2.000
#
#        "R1_data" 10 "R2_data" 5 "R3_data" 10000 "R4_data" 8000 "R5_data" 10000 "W_data" 0.0002 "L_data" 1e-05  \
# 0                                                0.9999
# 1                                                0.9999
# 2                                                0.9999
# 3                                                0.9999
# 4                                                0.9999
# ...                                                 ...
# 3996                                            -0.8846
# 3997                                            -0.8846
# 3998                                            -0.8847
# 3999                                            -0.8847
# 4000                                            -0.8847
#
#        "R1_data" 255 "R2_data" 128 "R3_data" 255000 "R4_data" 204000 "R5_data" 255000 "W_data" 0.0005 "L_data" 4e-05  \
# 0                                                 0.999
# 1                                                 0.999
# 2                                                 0.999
# 3                                                 0.999
# 4                                                 0.999
# ...                                                 ...
# 3996                                             -1.113
# 3997                                             -1.113
# 3998                                             -1.113
# 3999                                             -1.113
# 4000                                             -1.113
#
#        "R1_data" 378 "R2_data" 66 "R3_data" 132000 "R4_data" 106000 "R5_data" 378000 "W_data" 0.00065 "L_data" 2.5e-05  \
# 0                                                0.9971
# 1                                                0.9971
# 2                                                0.9971
# 3                                                0.9971
# 4                                                0.9971
# ...                                                 ...
# 3996                                            -1.7170
# 3997                                            -1.7170
# 3998                                            -1.7170
# 3999                                            -1.7170
# 4000                                            -1.7170
#
#        "R1_data" 316 "R2_data" 36 "R3_data" 439000 "R4_data" 253000 "R5_data" 316000 "W_data" 0.000725 "L_data" 1.8e-05  \
# 0                                                0.9962
# 1                                                0.9962
# 2                                                0.9962
# 3                                                0.9962
# 4                                                0.9962
# ...                                                 ...
# 3996                                            -1.8670
# 3997                                            -1.8670
# 3998                                            -1.8670
# 3999                                            -1.8670
# 4000                                            -1.8670
#
#        "R1_data" 469 "R2_data" 20 "R3_data" 347000 "R4_data" 82000 "R5_data" 163000 "W_data" 0.000538 "L_data" 2.1e-05  \
# 0                                                0.9987
# 1                                                0.9987
# 2                                                0.9987
# 3                                                0.9987
# 4                                                0.9987
# ...                                                 ...
# 3996                                            -2.0530
# 3997                                            -2.0530
# 3998                                            -2.0530
# 3999                                            -2.0530
# 4000                                            -2.0530
#
#        "R1_data" 240 "R2_data" 28 "R3_data" 423000 "R4_data" 118000 "R5_data" 87000 "W_data" 0.000706 "L_data" 6.4e-05  \
# 0                                                0.9997
# 1                                                0.9997
# 2                                                0.9997
# 3                                                0.9997
# 4                                                0.9997
# ...                                                 ...
# 3996                                            -1.8010
# 3997                                            -1.8010
# 3998                                            -1.8010
# 3999                                            -1.8010
# 4000                                            -1.8010
#
#        "R1_data" 454 "R2_data" 105 "R3_data" 393000 "R4_data" 241000 "R5_data" 56000 "W_data" 0.000444 "L_data" 5.3e-05  \
# 0                                                0.9999
# 1                                                0.9999
# 2                                                0.9999
# 3                                                0.9999
# 4                                                0.9999
# ...                                                 ...
# 3996                                            -1.4710
# 3997                                            -1.4710
# 3998                                            -1.4710
# 3999                                            -1.4720
# 4000                                            -1.4720
#
#        "R1_data" 393 "R2_data" 196 "R3_data" 332000 "R4_data" 290000 "R5_data" 117000 "W_data" 0.000219 "L_data" 1.6e-05  \
# 0                                                0.9995
# 1                                                0.9995
# 2                                                0.9995
# 3                                                0.9995
# 4                                                0.9995
# ...                                                 ...
# 3996                                            -1.0990
# 3997                                            -1.0990
# 3998                                            -1.0990
# 3999                                            -1.0990
# 4000                                            -1.0990
#
#        "R1_data" 270 "R2_data" 13 "R3_data" 209000 "R4_data" 192000 "R5_data" 240000 "W_data" 0.000369 "L_data" 6.1e-05  \
# 0                                                0.9996
# 1                                                0.9996
# 2                                                0.9996
# 3                                                0.9996
# 4                                                0.9996
# ...                                                 ...
# 3996                                            -2.0040
# 3997                                            -2.0040
# 3998                                            -2.0040
# 3999                                            -2.0040
# 4000                                            -2.0040
#
#       ...  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...   ...
# 3996  ...
# 3997  ...
# 3998  ...
# 3999  ...
# 4000  ...
#
#        "R1_data" 313 "R2_data" 62 "R3_data" 284000 "R4_data" 146000 "R5_data" 193000 "W_data" 0.000283 "L_data" 5.1e-05  \
# 0                                                0.9997
# 1                                                0.9997
# 2                                                0.9997
# 3                                                0.9997
# 4                                                0.9997
# ...                                                 ...
# 3996                                            -1.6140
# 3997                                            -1.6140
# 3998                                            -1.6140
# 3999                                            -1.6140
# 4000                                            -1.6140
#
#        "R1_data" 420 "R2_data" 116 "R3_data" 330000 "R4_data" 158000 "R5_data" 453000 "W_data" 0.000602 "L_data" 2.2e-05  \
# 0                                                0.9963
# 1                                                0.9963
# 2                                                0.9963
# 3                                                0.9963
# 4                                                0.9963
# ...                                                 ...
# 3996                                            -1.5020
# 3997                                            -1.5020
# 3998                                            -1.5020
# 3999                                            -1.5020
# 4000                                            -1.5020
#
#        "R1_data" 450 "R2_data" 39 "R3_data" 177000 "R4_data" 35000 "R5_data" 239000 "W_data" 0.000789 "L_data" 2.6e-05  \
# 0                                                0.9978
# 1                                                0.9978
# 2                                                0.9978
# 3                                                0.9978
# 4                                                0.9978
# ...                                                 ...
# 3996                                            -1.9360
# 3997                                            -1.9360
# 3998                                            -1.9360
# 3999                                            -1.9360
# 4000                                            -1.9360
#
#        "R1_data" 144 "R2_data" 8 "R3_data" 361000 "R4_data" 280000 "R5_data" 422000 "W_data" 0.000264 "L_data" 3.4e-05  \
# 0                                                 0.999
# 1                                                 0.999
# 2                                                 0.999
# 3                                                 0.999
# 4                                                 0.999
# ...                                                 ...
# 3996                                             -2.010
# 3997                                             -2.010
# 3998                                             -2.010
# 3999                                             -2.010
# 4000                                             -2.010
#
#        "R1_data" 389 "R2_data" 131 "R3_data" 116000 "R4_data" 84000 "R5_data" 177000 "W_data" 0.000564 "L_data" 6.4e-05  \
# 0                                                0.9995
# 1                                                0.9995
# 2                                                0.9995
# 3                                                0.9995
# 4                                                0.9995
# ...                                                 ...
# 3996                                            -1.3560
# 3997                                            -1.3560
# 3998                                            -1.3560
# 3999                                            -1.3560
# 4000                                            -1.3560
#
#        "R1_data" 267 "R2_data" 70 "R3_data" 483000 "R4_data" 378000 "R5_data" 55000 "W_data" 0.000714 "L_data" 1.9e-05  \
# 0                                                0.9994
# 1                                                0.9994
# 2                                                0.9994
# 3                                                0.9994
# 4                                                0.9994
# ...                                                 ...
# 3996                                            -1.5030
# 3997                                            -1.5030
# 3998                                            -1.5030
# 3999                                            -1.5030
# 4000                                            -1.5030
#
#        "R1_data" 385 "R2_data" 45 "R3_data" 364000 "R4_data" 234000 "R5_data" 97000 "W_data" 0.000681 "L_data" 6.1e-05  \
# 0                                                0.9997
# 1                                                0.9997
# 2                                                0.9997
# 3                                                0.9997
# 4                                                0.9997
# ...                                                 ...
# 3996                                            -1.8040
# 3997                                            -1.8040
# 3998                                            -1.8040
# 3999                                            -1.8040
# 4000                                            -1.8040
#
#        "R1_data" 202 "R2_data" 14 "R3_data" 181000 "R4_data" 87000 "R5_data" 281000 "W_data" 0.000306 "L_data" 6.9e-05  \
# 0                                                0.9996
# 1                                                0.9996
# 2                                                0.9996
# 3                                                0.9996
# 4                                                0.9996
# ...                                                 ...
# 3996                                            -1.9400
# 3997                                            -1.9400
# 3998                                            -1.9400
# 3999                                            -1.9400
# 4000                                            -1.9400
#
#        "R1_data" 447 "R2_data" 137 "R3_data" 426000 "R4_data" 283000 "R5_data" 36000 "W_data" 0.000606 "L_data" 3.9e-05  \
# 0                                                0.9998
# 1                                                0.9998
# 2                                                0.9998
# 3                                                0.9998
# 4                                                0.9998
# ...                                                 ...
# 3996                                            -1.3420
# 3997                                            -1.3420
# 3998                                            -1.3420
# 3999                                            -1.3420
# 4000                                            -1.3420
#
#        "R1_data" 243 "R2_data" 54 "R3_data" 265000 "R4_data" 110000 "R5_data" 99000 "W_data" 0.000797 "L_data" 2.7e-05
# 0                                                0.9991
# 1                                                0.9991
# 2                                                0.9991
# 3                                                0.9991
# 4                                                0.9991
# ...                                                 ...
# 3996                                            -1.5970
# 3997                                            -1.5970
# 3998                                            -1.5970
# 3999                                            -1.5970
# 4000                                            -1.5970
#
# [4001 rows x 10009 columns]

# %% [markdown]
# # 无用列
# 9
# [0, 1002, 2003, 3004, 3043, 3045, 5007, 7008, 8010]3044

# %%
f1 = data.iloc[:,1]
f1
# Out:
# 0       0.9999
# 1       0.9999
# 2       0.9999
# 3       0.9999
# 4       0.9999
#          ...
# 3996   -0.8846
# 3997   -0.8846
# 3998   -0.8847
# 3999   -0.8847
# 4000   -0.8847
# Name:  "R1_data" 10 "R2_data" 5 "R3_data" 10000 "R4_data" 8000 "R5_data" 10000 "W_data" 0.0002 "L_data" 1e-05, Length: 4001, dtype: float64

# %%
result1 = [[f2 for f2 in range(4001)]]
for i in range(1,1002):
    
    f1 = data.iloc[:,i]
    F = [float(f) for f in f1.to_numpy()]
    result1.append(F)
a= torch.tensor(result1)
a.shape
# Out:
# torch.Size([1002, 4001])

# %%
result2 = []
for i in range(1003,2003):
    
    f1 = data.iloc[:,i]
    F = [float(f) for f in f1.to_numpy()]
    result2.append(F)
a= torch.tensor(result2)
a.shape
# Out:
# torch.Size([1000, 4001])

# %%
result3 = []
for i in range(2004,3004):
    
    f1 = data.iloc[:,i]
    F = [float(f) for f in f1.to_numpy()]
    result3.append(F)
a= torch.tensor(result3)
a.shape
# Out:
# torch.Size([1000, 4001])

# %%
result4 = []
for i in range(3005,3043):
    
    f1 = data.iloc[:,i]
    F = [float(f) for f in f1.to_numpy()]
    result4.append(F)
a= torch.tensor(result4)
a.shape
# Out:
# torch.Size([38, 4001])

# %%
result5 = []
for i in range(3046, 5007):
    
    f1 = data.iloc[:,i]
    F = [float(f) for f in f1.to_numpy()]
    result5.append(F)
a= torch.tensor(result5)
a.shape
# Out:
# torch.Size([1961, 4001])

# %%
result6 = []
for i in range(5008, 7008):
    
    f1 = data.iloc[:,i]
    F = [float(f) for f in f1.to_numpy()]
    result6.append(F)
a= torch.tensor(result6)
a.shape
# Out:
# torch.Size([2000, 4001])

# %%
result7 = []
for i in range(7009, 8010):
    
    f1 = data.iloc[:,i]
    F = [float(f) for f in f1.to_numpy()]
    result7.append(F)
a= torch.tensor(result7)
a.shape
# Out:
# torch.Size([1001, 4001])

# %%
result8 = []
for i in range(8011, 10009):
    
    f1 = data.iloc[:,i]
    F = [float(f) for f in f1.to_numpy()]
    result8.append(F)
a= torch.tensor(result8)
a.shape
# Out:
# torch.Size([1998, 4001])

# %%
result = result1+result2+result3+result4+result5+result6+result7+result8
a= torch.tensor(result)
a.shape
# Out:
# torch.Size([10000, 4001])

# %%
a
# Out:
# tensor([[ 0.0000e+00,  1.0000e+00,  2.0000e+00,  ...,  3.9980e+03,
#           3.9990e+03,  4.0000e+03],
#         [ 9.9990e-01,  9.9990e-01,  9.9990e-01,  ..., -8.8470e-01,
#          -8.8470e-01, -8.8470e-01],
#         [ 9.9900e-01,  9.9900e-01,  9.9900e-01,  ..., -1.1130e+00,
#          -1.1130e+00, -1.1130e+00],
#         ...,
#         [ 9.9960e-01,  9.9960e-01,  9.9960e-01,  ..., -1.9400e+00,
#          -1.9400e+00, -1.9400e+00],
#         [ 9.9980e-01,  9.9980e-01,  9.9980e-01,  ..., -1.3420e+00,
#          -1.3420e+00, -1.3420e+00],
#         [ 9.9910e-01,  9.9910e-01,  9.9910e-01,  ..., -1.5970e+00,
#          -1.5970e+00, -1.5970e+00]])

# %%
np.savetxt('./data/inv_output.csv', a, fmt='%f', delimiter=',')
